# %%
import json

with open('topic-info.json') as f:
    data = json.load(f)

# Output: {'name': 'Bob', 'languages': ['English', 'Fench']}

# %%
topic_term_dists = data["topic_term_dists"]
doc_topic_dists = data["doc_topic_dists"]
doc_lengths = data["doc_lengths"]
vocab = data["vocab"]
term_frequency = data["term_frequency"]

# %%
print(doc_lengths)
# Out:
# [3274, 2393, 1480, 1765, 2888, 3434, 1725, 2029]

# %%
import pyLDAvis

py_lda_prepared_data = pyLDAvis.prepare(topic_term_dists, doc_topic_dists, doc_lengths, vocab, term_frequency)
#
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))

# %%
pyLDAvis.display(py_lda_prepared_data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el723081402075276414008609546825"></div>
# <script type="text/javascript">
#
# ...
